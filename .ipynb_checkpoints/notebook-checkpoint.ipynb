# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** WAHYUNI FAJRIN ROSYIDAH
# - **Email:** wahyunirosyidah@gmail.com
# - **ID Dicoding:** M587B4KX4461

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Berapakah Persentase Total Penyewaan Sepeda Berdasarkan Status Keanggotaan?
# - Berapakah Total Penyewaan Per Bulan Selama Tahun 2011-2012?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import calendar

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load day table

# %%
day_df=pd.read_csv("dashboard/day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# The code above displays the first 5 rows in day_df

# %% [markdown]
# #### Load hour table

# %%
hour_df=pd.read_csv("dashboard/hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# The code above displays the first 5 rows in hours_df

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Menilai Data day_df

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# Ditemukan kesalahan tipe data pada kolom dteday. Kolom tersebut harusnya direpresentasikan sebagai tipe data datetime, bukan object (ini digunakan untuk tipe data string).

# %% [markdown]
# ##### Memeriksa duplikasi pada tabel day

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menilai Data hour_df

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# **Insight:**
#
# Terdapat kesalahan tipe data untuk kolom dteday.  Kolom tersebut harusnya direpresentasikan sebagai tipe data datetime, bukan object (ini digunakan untuk tipe data string).

# %% [markdown]
# ##### Memeriksa duplikasi pada tabel hour

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Pada proses assessing data, ditemukan kesalahan yang sama pada data day_df dan hour_df. Kesalahan yang ditemukan adalah tipe data pada kolom dteday yang didefinisikan sebagai object. Data yang disimpan oleh kolom dteday adalah data tanggal, oleh karena itu tipe data yang seharusnya dimiliki oleh kolom dteday adalah datetime.
#
# Pada proses cleaning data ini akan dilakukan perubahan tipe data kolom dteday yang dimiliki oleh data dari day_df dan hour_df.

# %% [markdown]
# #### Clean day_df data

# %% [markdown]
# ##### Menangani salah tipe data pada kolom dteday pada day_df

# %%
datetime_columns = ["dteday"]
 
for column in datetime_columns:
  day_df[column] = pd.to_datetime(day_df[column])
  
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %% [markdown]
# **Insight:**
#
# Berdasarkan hasil yang diperoleh, tipe data pada kolom dteday yang sebelumnya adalah object berhasil diubah ke tipe data yang seharusnya yaitu datetime

# %% [markdown]
# ##### Menangani salah tipe data pada kolom dteday pada hour_df

# %%
datetime2_columns = ["dteday"]
 
for column in datetime_columns:
  hour_df[column] = pd.to_datetime(hour_df[column])
  
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %% [markdown]
# **Insight:**
#
# Berdasarkan hasil yang diperoleh, tipe data pada kolom dteday yang sebelumnya adalah object berhasil diubah ke tipe data yang seharusnya yaitu datetime

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore day_df data

# %%
day_df.describe(include="all")
# Out:
#           instant               dteday      season          yr        mnth  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           holiday     weekday  workingday  weathersit        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.028728    2.997264    0.683995    1.395349    0.495385    0.474354
# ...

# %% [markdown]
# **Insight:**
#
# Berdasarkan rangkuman parameter statistik diatas, diperoleh jumlah penyewa paling sedikit adalah 22 penyewa dan yang terbanyak adalah 8.714 orang penyewa dalam satu harinya. Pada penyewa casual, per harinya paling rendah adalah 2 orang penyewa dan 3.410 adalah jumlah penyewa tertingginya dalam satu harinya. Sedangkan, pada penyewa registered, jumlah penyewa paling sedikit adalah 20 orang penyewa dan jumlah terbanyak adalah 6946 orang dalam satu harinya

# %%
total_casual = day_df['casual'].sum()
total_registered = day_df['registered'].sum()
total_all=total_casual+total_registered
print("Total Sewa Casual Users:", total_casual)
print("Total Sewa Registered Users:", total_registered)
print("Total Sewa All Users:", total_all)
# Out:
# Total Sewa Casual Users: 620017
# Total Sewa Registered Users: 2672662
# Total Sewa All Users: 3292679

# %% [markdown]
# Berdasarkan hasil diatas didapatkan total dari seluruh penyewa selama tahun 2011 yang tidak terdaftar adalah sebanyak 620.017 penyewa dan yang terdaftar sebanyak 2.672.662 penyewa. Total dari keseluruhan jumlah penyewa pada tahun 2011 adalah 3.292.679 penyewa.

# %%
day_df['year'] = day_df['dteday'].dt.year
day_df['month'] = day_df['dteday'].dt.month
monthly_rentals = day_df.groupby(['year', 'month'])['cnt'].sum().reset_index()
print(monthly_rentals)
# Out:
#     year  month     cnt
# 0   2011      1   38189
# 1   2011      2   48215
# 2   2011      3   64045
# 3   2011      4   94870
# 4   2011      5  135821
# 5   2011      6  143512
# 6   2011      7  141341
# 7   2011      8  136691
# 8   2011      9  127418
# 9   2011     10  123511
# 10  2011     11  102167
# 11  2011     12   87323
# 12  2012      1   96744
# 13  2012      2  103137
# 14  2012      3  164875
# 15  2012      4  174224
# 16  2012      5  195865
# 17  2012      6  202830
# 18  2012      7  203607
# 19  2012      8  214503
# 20  2012      9  218573
# 21  2012     10  198841
# 22  2012     11  152664
# 23  2012     12  123713

# %%
day_df['year'] = day_df['dteday'].dt.year
yearly_rentals = day_df.groupby(['year'])['cnt'].sum().reset_index()
day_df.groupby(by="year").agg({
    "registered":"sum",
    "casual":"sum",
    "cnt": "sum"
})
# Out:
#       registered  casual      cnt
# year
# 2011      995851  247252  1243103
# 2012     1676811  372765  2049576

# %%
day_df.groupby(by="year").agg({
    "cnt": ["max", "min", "mean", "std"]
})
# Out:
#        cnt
#        max  min         mean          std
# year
# 2011  6043  431  3405.761644  1378.753666
# 2012  8714   22  5599.934426  1788.667868

# %% [markdown]
# ### Explore hour_df data

# %%
hour_df.describe(include="all")
# Out:
#           instant                         dteday        season            yr  \
# count  17379.0000                          17379  17379.000000  17379.000000
# mean    8690.0000  2012-01-02 04:08:34.552045568      2.501640      0.502561
# min        1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%     4345.5000            2011-07-04 00:00:00      2.000000      0.000000
# 50%     8690.0000            2012-01-02 00:00:00      3.000000      1.000000
# 75%    13034.5000            2012-07-02 00:00:00      3.000000      1.000000
# max    17379.0000            2012-12-31 00:00:00      4.000000      1.000000
# std     5017.0295                            NaN      1.106918      0.500008
#
#                mnth            hr       holiday       weekday    workingday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       6.537775     11.546752      0.028770      3.003683      0.682721
# ...

# %% [markdown]
# Berdasarkan rangkuman parameter statistik diatas, diperoleh jumlah penyewa paling sedikit adalah 1 penyewa dan yang terbanyak adalah 977 penyewa per jamnya. Pada penyewa casual, per harinya paling rendah adalah 0 penyewa dan 367 adalah jumlah penyewa tertingginya per jamnya. Sedangkan, pada penyewa registered, jumlah penyewa paling sedikit adalah 0 orang penyewa dan jumlah terbanyak adalah 886 orang perjamnya.

# %%
hour_df.groupby(by="hr").agg({
    "cnt": ["max", "min", "mean", "std"]
})
# Out:
#     cnt
#     max min        mean         std
# hr
# 0   283   2   53.898072   42.307910
# 1   168   1   33.375691   33.538727
# 2   132   1   22.869930   26.578642
# 3    79   1   11.727403   13.239190
# 4    28   1    6.352941    4.143818
# 5    66   1   19.889819   13.200765
# 6   213   1   76.044138   55.084348
# 7   596   1  212.064649  161.441936
# 8   839   5  359.011004  235.189285
# 9   426  14  219.309491   93.703458
# 10  539   8  173.668501  102.205413
# 11  663  10  208.143054  127.495536
# 12  776   3  253.315934  145.081134
# 13  760  11  253.661180  148.107657
# 14  750  12  240.949246  147.271574
# 15  750   7  251.233196  144.632541
# 16  783  11  311.983562  148.682618
# 17  976  15  461.452055  232.656611
# 18  977  23  425.510989  224.639304
# 19  743  11  311.523352  161.050359
# 20  567  11  226.030220  119.670164
# 21  584   6  172.314560   89.788893
# 22  502   9  131.335165   69.937782
# 23  256   2   87.831044   50.846889

# %%
hour_df.groupby(by="weathersit").agg({
    "cnt": ["max", "min", "mean", "std"]
})
# Out:
#             cnt
#             max min        mean         std
# weathersit
# 1           977   1  204.869272  189.487773
# 2           957   1  175.165493  165.431589
# 3           891   1  111.579281  133.781045
# 4           164  23   74.333333   77.925178

# %%
hour_df.rename(columns={
    "cnt": "total"
}, inplace=True)

hour_df.groupby(by="weathersit").agg({
    "registered": ["min", "max", "mean"],
    "casual": ["min", "max", "mean"],
    "total": ["min", "max", "mean"]
})
# Out:
#            registered                  casual                 total       \
#                   min  max        mean    min  max       mean   min  max
# weathersit
# 1                   0  886  164.323841      0  367  40.545431     1  977
# 2                   0  822  145.570202      0  350  29.595290     1  957
# 3                   0  791   95.523608      0  263  16.055673     1  891
# 4                  22  158   71.666667      1    6   2.666667    23  164
#
#
#                   mean
# weathersit
# 1           204.869272
# 2           175.165493
# 3           111.579281
# 4            74.333333

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Berapakah Persentase Total Penyewaan Sepeda Berdasarkan Status Keanggotaan?

# %%
membership = ('Registered', 'Casual')
total = (total_registered, total_casual)
colors = ('#F4D06F', '#73E2A7')
explode = (0.1, 0)
 
plt.pie(
    x=total,
    labels=membership,
    autopct='%1.1f%%',
    colors=colors,
    explode=explode,
    startangle=90
    
)
plt.title('Persentase Demografi Penyewa (2011 dan 2012)')
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Berapakah Total Penyewaan Per Bulan Selama Tahun 2011?

# %% [markdown]
# ### Line Chart Total Penyewaan Per Bulan Selama Tahun 2011

# %%
monthly_rentals = day_df.groupby(['year', 'month'])['cnt'].sum().reset_index()

plt.figure(figsize=(10,6))
for year in monthly_rentals['year'].unique():
    monthly_rentals_data = monthly_rentals[monthly_rentals['year'] == year]
    plt.plot(monthly_rentals_data['month'], 
             monthly_rentals_data['cnt'], 
             label=f'Tahun {year}',
             marker='o', 
             linewidth=2
            )
    
plt.xticks(ticks=range(1, 13), labels=list(calendar.month_name[1:]), rotation=45)
plt.title('Total Penyewa Sepeda per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Total Penyewa')
plt.legend()
plt.tight_layout()
plt.show()

# %%
monthly_avg_rentals = monthly_rentals.groupby('month')['cnt'].mean().reset_index()

monthly_avg_rentals['month_num'] = range(1, 13)

plt.figure(figsize=(10, 6))
sns.regplot(x='month_num', y='cnt', data=monthly_avg_rentals, marker='o', color='blue')

plt.xticks(ticks=range(1, 13), labels=list(calendar.month_name[1:]), rotation=45)
plt.title('Rata-Rata Jumlah Penyewa Sepeda per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Nilai Rata-Rata Penyewa')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9904\642361988.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# Pada visualisasi data di atas, garis biru menunjukkan garis korelasi dari hasil regression sedangkan pita di sekitar garis tersebut menunjukkan confidence level dari hasil regression tersebut. Semakin kecil bentuk pita yang dihasilkan menandakan tingkat confidence level yang tinggi.

# %%
# Menghitung korelasi antara kolom 'cnt' (jumlah penyewa) dan 'weathersit' (kondisi cuaca)
correlation = hour_df['cnt'].corr(hour_df['weathersit'])

# Menampilkan hasil korelasi
print(f"Korelasi antara jumlah penyewa dan kondisi cuaca: {correlation}")

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[183], line 2
#       1 # Menghitung rata-rata jumlah penyewa berdasarkan kondisi cuaca
# ----> 2 weather_avg_rentals = hour_df.groupby('weathersit')['cnt'].mean().reset_index()
#       4 # Membuat line chart
#       5 plt.figure(figsize=(10, 6))
#
# File ~\.virtualenvs\submission-dicoding-HUf7UY7X\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# ...

# %%
hour_avg_rentals = hour_df.groupby('hr')['cnt'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.regplot(x='hr', y='cnt', data=hour_avg_rentals, marker='o', color='blue')

plt.xticks(ticks=range(0, 24), rotation=45)
plt.title('Rata-Rata Jumlah Penyewa Sepeda per Jam')
plt.xlabel('Bulan')
plt.ylabel('Nilai Rata-Rata Penyewa')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1.  Berapakah Persentase Total Penyewaan Sepeda Berdasarkan Status Keanggotaan?
#   Diperoleh hasil bahwa persentase total penyewaan sepeda tahun 2011 berdasarkan keanggotaannya adalah:
#     - Registered(penyewa yang terdaftar) : 81.2%
#     - Casual(penyewa yang tidak terdaftar) : 18.8%
#
# 2. Berapakah Total Penyewaan Per Bulan Selama Tahun 2011?
#   Berdasarkan hasil yang diperoleh, total penyewaan sepeda pada bulan januari sebanyak 38.189 penyewa, bulan februari sebanyak 48.215 penyewa, bulan maret sebanyak 64.045 penyewa, bulan april sebanyak 94.870 penyewa, bulan maret sebanyak 135.821 penyewa.
#
# Berdasarkan data yang ada, dapat disimpulkan bahwa jumlah penyewaan sepeda oleh pengguna dengan status terdaftar lebih tinggi dibandingkan dengan pengguna dengan status kasual.
